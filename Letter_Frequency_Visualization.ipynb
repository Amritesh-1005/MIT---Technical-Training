# %% [markdown]
# <a href="https://colab.research.google.com/github/Amritesh-1005/MIT---Technical-Training/blob/main/Letter_Frequency_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from collections import Counter

name = "Amritesh"

# Count each character
char_count = Counter(name)

# Characters and frequencies
characters = list(char_count.keys())
frequencies = list(char_count.values())

# Create bar graph
plt.figure(figsize=(8, 5))
plt.bar(characters, frequencies)

plt.title("Character Frequency in 'Amritesh'")
plt.xlabel("Characters")
plt.ylabel("Frequency")

plt.show()

# %%
import matplotlib.pyplot as plt
from collections import Counter

name = "Missisippi"

# Count each character
char_count = Counter(name)

# Characters and frequencies
characters = list(char_count.keys())
frequencies = list(char_count.values())

# Create bar graph
plt.figure(figsize=(8, 5))
plt.bar(characters, frequencies)

plt.title("Character Frequency in 'Missisippi'")
plt.xlabel("Characters")
plt.ylabel("Frequency")

plt.show()
